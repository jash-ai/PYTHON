# %% [markdown]
# <a href="https://colab.research.google.com/github/jash-ai/PYTHON/blob/main/YAHOO_FINANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Download Financial Dataset Using Yahoo Finance in Python | A Complete Guide

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/06/download-financial-dataset-using-yahoo-finance-in-python-a-complete-guide/

# %%
# !pip install yfinance
# !pip install yahoofinancials
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.16-py3-none-any.whl size=28709 sha256=11fffb9458d9292d66b2ec7a5744443a34f7f194054c0718dc4080503085e93f
#   Stored in directory: /root/.cache/pip/wheels/fd/fe/c4/4b17989f30abf08d147a72cd1097ae0f6b1a1dd070f3abf726
# Successfully built yahoofinancials
# ...

# %%
#We need to load the following libraries:

import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
#download the stock aapl which is apple
aapl_df = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
aapl_df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099450
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094261
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087343
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089504
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092099
# ...                ...         ...         ...         ...         ...
# 2023-10-12  180.070007  182.339996  179.039993  180.710007  180.710007
# 2023-10-13  181.419998  181.929993  178.139999  178.850006  178.850006
# 2023-10-16  176.750000  179.080002  176.509995  178.720001  178.720001
# 2023-10-17  176.649994  178.419998  174.800003  177.149994  177.149994
# 2023-10-18  175.580002  177.580002  175.110001  175.839996  175.839996
#
#                Volume
# Date
# 1980-12-12  469033600
# 1980-12-15  175884800
# 1980-12-16  105728000
# ...

# %%
##apple closing price
ticker = yf.Ticker('AAPL')
aapl_df = ticker.history(period="5y")
aapl_df['Close'].plot(title="APPLE's stock price")
# Out:
# <Axes: title={'center': "APPLE's stock price"}, xlabel='Date'>

# %% [markdown]
# METHOD 2

# %%
##PROVIDE THE TICKER AND THE START AND END DATE AND TIMEINTERVALS IS WEEKLY
#
yahoo_financials = YahooFinancials('AAPL')
data = yahoo_financials.get_historical_price_data(start_date='2019-01-01',
                                                  end_date='2019-12-31',
                                                  time_interval='weekly')
aapl_df = pd.DataFrame(data['AAPL']['prices'])
aapl_df = aapl_df.drop('date', axis=1).set_index('formatted_date')
aapl_df.head()
# Out:
#                      high        low       open      close     volume  \
# formatted_date
# 2019-01-01      39.712502  35.500000  38.722500  36.982498  966947200
# 2019-01-08      38.632500  37.130001  37.389999  37.500000  725470000
# 2019-01-15      39.470001  37.512501  37.567501  39.205002  491411200
# 2019-01-22      39.532501  37.924999  39.102501  39.075001  554774800
# 2019-01-29      42.915001  38.527500  39.062500  42.812500  830400800
#
#                  adjclose
# formatted_date
# 2019-01-01      35.542965
# 2019-01-08      36.040333
# 2019-01-15      37.678963
# 2019-01-22      37.554024
# 2019-01-29      41.146042

# %%
yahoo_financials = YahooFinancials('BTC-USD')
data=yahoo_financials.get_historical_price_data("2019-07-10", "2021-05-30", "monthly")
btc_df = pd.DataFrame(data['BTC-USD']['prices'])
btc_df = btc_df.drop('date', axis=1).set_index('formatted_date')
btc_df.head()
# Out:
#                         high          low          open        close  \
# formatted_date
# 2019-08-01      12273.821289  9421.629883  10077.442383  9630.664062
# 2019-09-01      10898.761719  7830.758789   9630.592773  8293.868164
# 2019-10-01      10021.744141  7446.988770   8299.720703  9199.584961
# 2019-11-01       9505.051758  6617.166992   9193.992188  7569.629883
# 2019-12-01       7743.431641  6540.049316   7571.616211  7193.599121
#
#                       volume     adjclose
# formatted_date
# 2019-08-01      533984971734  9630.664062
# 2019-09-01      480544963230  8293.868164
# 2019-10-01      595205134748  9199.584961
# 2019-11-01      676919523650  7569.629883
# 2019-12-01      633790373416  7193.599121
